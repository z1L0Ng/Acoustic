# %% [markdown]
# # P5｜OPERA Overlap Reference
#
# **状态：Scientific HOLD。** 目的：记录 OPERA encoder/reference lane，并把标准预训练重叠、provenance 与 input-adapter 当作执行前硬 gate。

# %% [markdown]
# ## 唯一变量、四数据集 lane、输入输出与科学 gate
#
# matched comparator=P1；候选唯一变化是 non-HF reference encoder/package。ICBHI cycle flat4、SPRSound event binary/raw7、KAUH recording raw9（B/D/E 同 patient）；HF 固定 native temporal reference，missing/gap 不是 negative。输入适配与输出 pooled/native logits 必须形成可验 contract。
#
# Verified boundary：OPERA standard pretraining 明确包含 ICBHI 与 HF；KAUH 只确认 benchmark/repository path，尚未证明进入标准 checkpoint pretraining。必须生成 dataset/checkpoint overlap matrix、revision/SHA 与 input-adapter verifier，并取得单独执行审批。该行不能称 clean generalization、zero-shot 或无重叠公平比较。

# %%
PIPELINE = {"id": "P5", "comparator": "P1_reference_only", "seed": 20260728, "split_policy": "match_P1", "overlap_gate": "required", "provenance_gate": "required", "input_adapter_gate": "required", "update_budget": None, "selection": None, "output_dir": "result/reproduce/P5_opera_overlap_reference", "receipt_path": "result/reproduce/P5_opera_overlap_reference/P5_receipt.json"}
raise RuntimeError("P5 Scientific HOLD until overlap, provenance, adapter, budget, selection, and approval receipts pass")

# %% [markdown]
# ## Receipt、结果表与 claim boundary
#
# receipt：standard-pretraining source/revision/checkpoint hashes、per-dataset overlap status/evidence、input-adapter contract、P1 parity、native metrics、warnings。
#
# | Dataset overlap / comparison | Result | Decision |
# |---|---:|---|
# | ICBHI、SPRSound、HF、KAUH；P5−P1 | Not run | HOLD |
#
# **Test Result = Not run。Decision = HOLD。仅 overlap-aware reference，不作 clean generalization claim。**
