# %% [markdown]
# # Download and first-pass audit: `icbhi_2017`
#
# This notebook is idempotent. It downloads approved source files into `dataset/raw/icbhi_2017/`, extracts original source files under `source_original/` when needed, and writes audit outputs to `dataset/processed/icbhi_2017/`.

# %%
from pathlib import Path

DATASET_ID = "icbhi_2017"
RAW_DIR = Path("../raw") / DATASET_ID
PROCESSED_DIR = Path("../processed") / DATASET_ID
SOURCE_URLS = ['https://bhichallenge.med.auth.gr/ICBHI_2017_Challenge']
EXPECTED_FILES = ['ICBHI_final_database.zip', 'events.zip', 'ICBHI_Challenge_demographic_information.txt', 'ICBHI_Challenge_diagnosis.txt', 'ICBHI_challenge_train_test.txt']

print(DATASET_ID)
print(RAW_DIR)
print(PROCESSED_DIR)

# %% [markdown]
# ## Execute workflow
#
# Run this cell only after user approval for this dataset download.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd()))
from phase1_dataset_workflow import main

main(["phase1_dataset_workflow.py", DATASET_ID])

# %% [markdown]
# ## Concise output preview
#
# Keep notebook outputs short; detailed artifacts live in `dataset/processed/<dataset_id>/`.

# %%
import pandas as pd

for name in ["file_inventory.csv", "audio_format_summary.csv", "label_schema.csv", "metadata_availability.csv", "class_distribution.csv"]:
    path = PROCESSED_DIR / name
    if path.exists():
        print("\n", name)
        display(pd.read_csv(path).head(10))
