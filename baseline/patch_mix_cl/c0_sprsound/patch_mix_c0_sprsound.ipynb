# %% [markdown]
# # Patch-Mix C0: SPRSound target-native reference
#
# This notebook is a lightweight execution guide for the tracked CLI package. It trains separate binary-broad and narrow-four Patch-Mix heads on official SPRSound train events, selects checkpoints only with a fixed patient-grouped internal validation fold, and evaluates official inter-subject events once. This is not zero-shot, pooled training, adaptation, or a published-paper reproduction. See `protocol.json` and `README.md` before execution.

# %%
from pathlib import Path

repo_root = Path.cwd().resolve()
if not (repo_root / 'baseline').is_dir():
    repo_root = repo_root.parents[2]
package = repo_root / 'baseline' / 'patch_mix_cl' / 'c0_sprsound'
print((package / 'protocol.json').read_text())

# %% [markdown]
# Use the exact fresh-checkout smoke and full commands in `README.md`. The notebook intentionally does not launch training automatically, does not embed generated output, and does not read official inter labels.
