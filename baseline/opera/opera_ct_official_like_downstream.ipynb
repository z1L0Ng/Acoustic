# %% [markdown]
# # OPERA-CT official-like frozen downstream extension
#
# Objective: evaluate audited 768-d OPERA-CT official-like features with the same controlled architecture and loss protocols as formal baseline v1. The feature path uses the official OPERA repository preprocessing/model route adapted to the local cycle-level ICBHI task and joined by unique `cycle_id`. It is not the OPERA paper's official ICBHI reproduction. Official test is not patient-independent because patients 156 and 218 cross train/test. Outputs are isolated under `result/icbhi_frozen_downstream/`.

# %%
from pathlib import Path
import os, sys
ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / 'baseline').exists(): ROOT = ROOT.parent
os.chdir(ROOT)
print('repo:', ROOT)
print('python:', sys.executable)

# %% [markdown]
# ## Architecture comparison
#
# Runs flat4 and binary with balanced LR once and class-weighted MLP1/MLP2 over seeds 20260712-20260714. StandardScaler and early stopping use official subtrain/grouped validation only.

# %%
from baseline.common.extension import run_extension_architecture_backbone
mode = 'full'
architecture_rows = run_extension_architecture_backbone('opera_ct_official_like', mode)
len(architecture_rows)

# %% [markdown]
# ## Flat4 loss comparison
#
# Fixes MLP2 and varies only unweighted CE, balanced class-weighted CE, focal loss (gamma=2, no alpha), and effective-number class-balanced CE (beta=0.9999).

# %%
from baseline.common.extension import run_extension_imbalance_backbone
imbalance_mode = 'full'
loss_rows = run_extension_imbalance_backbone('opera_ct_official_like', imbalance_mode)
len(loss_rows)
