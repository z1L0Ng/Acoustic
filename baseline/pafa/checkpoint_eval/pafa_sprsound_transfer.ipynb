# %% [markdown]
# # PAFA B1 frozen checkpoint to SPRSound inter
#
# Objective: run the accepted ICBHI-test-selected PAFA checkpoint container saved at epoch 100, whose predictive state was selected at best epoch 27, as a zero-target-tuning exploratory transfer. This notebook is a thin, auditable entry over the package CLI; it does not embed checkpoints, outputs, or target-side selection.

# %% [markdown]
# The exact target is 1,429 official inter-subject BioCAS2022 events. PAFA keeps its 16 kHz, 5 s repeat/truncate, raw-waveform `--nospec` preprocessing. Set the server-owned checkpoint paths and SHA256 values before executing. Run smoke and its verifier before full inference.

# %%
from pathlib import Path

dataset_root = Path("dataset/raw/sprsound")
result_root = Path("result/pafa_sprsound_transfer_<CHICAGO_TIMESTAMP>")
task_checkpoint = Path("<SERVER_PAFA_ACCEPTED_CONTAINER_EPOCH100>")
task_sha256 = "94afaed43a1546af26f9d8d99d2d27329cb8d348fd57cbe142d24310c68ca2b6"
beats_checkpoint = Path("<SERVER_BEATS_ITER3_PLUS_AS2M_CHECKPOINT>")

# %% [markdown]
# Use the exact commands in `README.md`. Keeping execution in the CLI preserves label isolation, checkpoint hashing, canonical result-root naming, and independent verification.
